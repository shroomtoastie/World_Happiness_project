# %%
import pandas as pd
import numpy
import matplotlib as plt
from pandas import DataFrame
import random

# %%
happy21_df = pd.read_csv("C:\\Users\\pwurt\\documents\\DA_pathway\\M3\\World_Happy\\World_Happiness_Report\\.venv\\happiness_report_22\\2021.csv")

happy21_df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# 3                 10.878           0.983                     73.0
# 4                 10.932           0.942                     72.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
# 1                         0.946       0.030                      0.179
# 2                         0.919       0.025                      0.292
# 3                         0.955       0.160                      0.673
# 4                         0.913       0.175                      0.338
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                      2.43                             1.446
# 1                      2.43                             1.502
# 2                      2.43                             1.566
# 3                      2.43                             1.482
# 4                      2.43                             1.501
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.106                                  0.741
# 1                         1.108                                  0.763
# 2                         1.079                                  0.816
# 3                         1.172                                  0.772
# 4                         1.079                                  0.753
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
# 1                                       0.686                     0.208
# 2                                       0.653                     0.204
# 3                                       0.698                     0.293
# 4                                       0.647                     0.302
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                    0.481                3.253
# 1                                    0.485                2.868
# 2                                    0.413                2.839
# 3                                    0.170                2.967
# 4                                    0.384                2.798

# %%
happy21_df.columns = happy21_df.columns.str.title()

happy21_df.head()
# Out:
#   Country Name Regional Indicator  Ladder Score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard Error Of Ladder Score  Upperwhisker  Lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged Gdp Per Capita  Social Support  Healthy Life Expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# 3                 10.878           0.983                     73.0
# 4                 10.932           0.942                     72.4
#
#    Freedom To Make Life Choices  Generosity  Perceptions Of Corruption  \
# 0                         0.949      -0.098                      0.186
# 1                         0.946       0.030                      0.179
# 2                         0.919       0.025                      0.292
# 3                         0.955       0.160                      0.673
# 4                         0.913       0.175                      0.338
#
#    Ladder Score In Dystopia  Explained By: Log Gdp Per Capita  \
# 0                      2.43                             1.446
# 1                      2.43                             1.502
# 2                      2.43                             1.566
# 3                      2.43                             1.482
# 4                      2.43                             1.501
#
#    Explained By: Social Support  Explained By: Healthy Life Expectancy  \
# 0                         1.106                                  0.741
# 1                         1.108                                  0.763
# 2                         1.079                                  0.816
# 3                         1.172                                  0.772
# 4                         1.079                                  0.753
#
#    Explained By: Freedom To Make Life Choices  Explained By: Generosity  \
# 0                                       0.691                     0.124
# 1                                       0.686                     0.208
# 2                                       0.653                     0.204
# 3                                       0.698                     0.293
# 4                                       0.647                     0.302
#
#    Explained By: Perceptions Of Corruption  Dystopia + Residual
# 0                                    0.481                3.253
# 1                                    0.485                2.868
# 2                                    0.413                2.839
# 3                                    0.170                2.967
# 4                                    0.384                2.798

# %%
happy21_df.columns
# Out:
# Index(['Country Name', 'Regional Indicator', 'Ladder Score',
#        'Standard Error Of Ladder Score', 'Upperwhisker', 'Lowerwhisker',
#        'Logged Gdp Per Capita', 'Social Support', 'Healthy Life Expectancy',
#        'Freedom To Make Life Choices', 'Generosity',
#        'Perceptions Of Corruption', 'Ladder Score In Dystopia',
#        'Explained By: Log Gdp Per Capita', 'Explained By: Social Support',
#        'Explained By: Healthy Life Expectancy',
#        'Explained By: Freedom To Make Life Choices',
#        'Explained By: Generosity', 'Explained By: Perceptions Of Corruption',
#        'Dystopia + Residual'],
#       dtype='object')

# %%
print(happy21_df.isnull().any().any())
# Out:
# False

# %%
happy21_df = happy21_df.rename(columns={'Country Name': 'Country', 'Regional Indicator': 'Region', 'Ladder Score': 'Happiness Score 21'})

# %%
happy21_df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Score 21',
#        'Standard Error Of Ladder Score', 'Upperwhisker', 'Lowerwhisker',
#        'Logged Gdp Per Capita', 'Social Support', 'Healthy Life Expectancy',
#        'Freedom To Make Life Choices', 'Generosity',
#        'Perceptions Of Corruption', 'Ladder Score In Dystopia',
#        'Explained By: Log Gdp Per Capita', 'Explained By: Social Support',
#        'Explained By: Healthy Life Expectancy',
#        'Explained By: Freedom To Make Life Choices',
#        'Explained By: Generosity', 'Explained By: Perceptions Of Corruption',
#        'Dystopia + Residual'],
#       dtype='object')

# %%
cols_to_drop21 = ['Standard Error Of Ladder Score', 'Upperwhisker', 'Lowerwhisker', 'Logged Gdp Per Capita', 'Generosity', 'Perceptions Of Corruption', 'Ladder Score In Dystopia', 'Explained By: Log Gdp Per Capita', 'Explained By: Social Support', 'Explained By: Healthy Life Expectancy', 'Explained By: Freedom To Make Life Choices', 'Explained By: Generosity', 'Explained By: Perceptions Of Corruption', 'Dystopia + Residual', ]

happy21_df = happy21_df.drop(columns = cols_to_drop21)

# %%
happy21_df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Score 21', 'Social Support',
#        'Healthy Life Expectancy', 'Freedom To Make Life Choices'],
#       dtype='object')

# %%
happy21_df.tail()
# Out:
#          Country              Region  Happiness Score 21  Social Support  \
# 144      Lesotho  Sub-Saharan Africa               3.512           0.787
# 145     Botswana  Sub-Saharan Africa               3.467           0.784
# 146       Rwanda  Sub-Saharan Africa               3.415           0.552
# 147     Zimbabwe  Sub-Saharan Africa               3.145           0.750
# 148  Afghanistan          South Asia               2.523           0.463
#
#      Healthy Life Expectancy  Freedom To Make Life Choices
# 144                   48.700                         0.715
# 145                   59.269                         0.824
# 146                   61.400                         0.897
# 147                   56.201                         0.677
# 148                   52.493                         0.382

# %%
happy21_df.tail(20)
# Out:
#           Country                        Region  Happiness Score 21  \
# 129     Swaziland            Sub-Saharan Africa               4.308
# 130       Comoros            Sub-Saharan Africa               4.289
# 131         Egypt  Middle East and North Africa               4.283
# 132      Ethiopia            Sub-Saharan Africa               4.275
# 133    Mauritania            Sub-Saharan Africa               4.227
# 134    Madagascar            Sub-Saharan Africa               4.208
# 135          Togo            Sub-Saharan Africa               4.107
# 136        Zambia            Sub-Saharan Africa               4.073
# 137  Sierra Leone            Sub-Saharan Africa               3.849
# 138         India                    South Asia               3.819
# 139       Burundi            Sub-Saharan Africa               3.775
# 140         Yemen  Middle East and North Africa               3.658
# 141      Tanzania            Sub-Saharan Africa               3.623
# 142         Haiti   Latin America and Caribbean               3.615
# 143        Malawi            Sub-Saharan Africa               3.600
# 144       Lesotho            Sub-Saharan Africa               3.512
# 145      Botswana            Sub-Saharan Africa               3.467
# 146        Rwanda            Sub-Saharan Africa               3.415
# 147      Zimbabwe            Sub-Saharan Africa               3.145
# 148   Afghanistan                    South Asia               2.523
#
#      Social Support  Healthy Life Expectancy  Freedom To Make Life Choices
# 129           0.770                   50.833                         0.647
# 130           0.626                   57.349                         0.548
# 131           0.750                   61.998                         0.749
# 132           0.764                   59.000                         0.752
# 133           0.795                   57.161                         0.561
# 134           0.686                   59.305                         0.552
# 135           0.569                   54.914                         0.619
# 136           0.708                   55.809                         0.782
# 137           0.630                   51.651                         0.717
# 138           0.603                   60.633                         0.893
# 139           0.490                   53.400                         0.626
# 140           0.832                   57.122                         0.602
# 141           0.702                   57.999                         0.833
# 142           0.540                   55.700                         0.593
# 143           0.537                   57.948                         0.780
# 144           0.787                   48.700                         0.715
# 145           0.784                   59.269                         0.824
# 146           0.552                   61.400                         0.897
# 147           0.750                   56.201                         0.677
# 148           0.463                   52.493                         0.382

# %%
region_country = happy21_df.groupby('Region')['Country'].count().sort_values(ascending=True)

region_country
# Out:
# Region
# North America and ANZ                  4
# East Asia                              6
# South Asia                             7
# Southeast Asia                         9
# Commonwealth of Independent States    12
# Central and Eastern Europe            17
# Middle East and North Africa          17
# Latin America and Caribbean           20
# Western Europe                        21
# Sub-Saharan Africa                    36
# Name: Country, dtype: int64

# %%
happy21_df.to_csv("happy21.csv", index=False)

# %% [markdown]
# ### Follow link for Tableau bar graph below: "2021 Region Happiness Country Count"
#
# https://public.tableau.com/views/2021RegionHappiness/2021RegionHappinessCountryCount?:language=en-US&publish=yes&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link

# %% [markdown]
# ## Happiness 2022 DF

# %%
happy_df22 = pd.read_csv("C:\\Users\\pwurt\\documents\\DA_pathway\\m3\\World_Happy\\World_Happiness_Report\\.venv\\happiness_report_22\\2022.csv")

happy_df22
# Out:
#      RANK      Country Happiness score Whisker-high Whisker-low  \
# 0       1      Finland           7,821        7,886       7,756
# 1       2      Denmark           7,636        7,710       7,563
# 2       3      Iceland           7,557        7,651       7,464
# 3       4  Switzerland           7,512        7,586       7,437
# 4       5  Netherlands           7,415        7,471       7,359
# ..    ...          ...             ...          ...         ...
# 142   143      Rwanda*           3,268        3,462       3,074
# 143   144     Zimbabwe           2,995        3,110       2,880
# 144   145      Lebanon           2,955        3,049       2,862
# 145   146  Afghanistan           2,404        2,469       2,339
# 146   147           xx             NaN          NaN         NaN
#
#     Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                        2,518                        1,892
# 1                        2,226                        1,953
# 2                        2,320                        1,936
# 3                        2,153                        2,026
# 4                        2,137                        1,945
# ..                         ...                          ...
# 142                      0,536                        0,785
# 143                      0,548                        0,947
# 144                      0,216                        1,392
# 145                      1,263                        0,758
# 146                        NaN                          NaN
#
#     Explained by: Social support Explained by: Healthy life expectancy  \
# 0                          1,258                                 0,775
# 1                          1,243                                 0,777
# 2                          1,320                                 0,803
# 3                          1,226                                 0,822
# 4                          1,206                                 0,787
# ..                           ...                                   ...
# 142                        0,133                                 0,462
# 143                        0,690                                 0,270
# 144                        0,498                                 0,631
# 145                        0,000                                 0,289
# 146                          NaN                                   NaN
#
#     Explained by: Freedom to make life choices Explained by: Generosity  \
# 0                                        0,736                    0,109
# 1                                        0,719                    0,188
# 2                                        0,718                    0,270
# 3                                        0,677                    0,147
# 4                                        0,651                    0,271
# ..                                         ...                      ...
# 142                                      0,621                    0,187
# 143                                      0,329                    0,106
# 144                                      0,103                    0,082
# 145                                      0,000                    0,089
# 146                                        NaN                      NaN
#
#     Explained by: Perceptions of corruption
# 0                                     0,534
# 1                                     0,532
# 2                                     0,191
# 3                                     0,461
# 4                                     0,419
# ..                                      ...
# 142                                   0,544
# 143                                   0,105
# 144                                   0,034
# 145                                   0,005
# 146                                     NaN
#
# [147 rows x 12 columns]

# %%
happy_df22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   RANK                                        147 non-null    int64
#  1   Country                                     147 non-null    object
#  2   Happiness score                             146 non-null    object
#  3   Whisker-high                                146 non-null    object
#  4   Whisker-low                                 146 non-null    object
#  5   Dystopia (1.83) + residual                  146 non-null    object
#  6   Explained by: GDP per capita                146 non-null    object
#  7   Explained by: Social support                146 non-null    object
#  8   Explained by: Healthy life expectancy       146 non-null    object
#  9   Explained by: Freedom to make life choices  146 non-null    object
#  10  Explained by: Generosity                    146 non-null    object
#  11  Explained by: Perceptions of corruption     146 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 13.9+ KB

# %%
happy_df22.tail()
# Out:
#      RANK      Country Happiness score Whisker-high Whisker-low  \
# 142   143      Rwanda*           3,268        3,462       3,074
# 143   144     Zimbabwe           2,995        3,110       2,880
# 144   145      Lebanon           2,955        3,049       2,862
# 145   146  Afghanistan           2,404        2,469       2,339
# 146   147           xx             NaN          NaN         NaN
#
#     Dystopia (1.83) + residual Explained by: GDP per capita  \
# 142                      0,536                        0,785
# 143                      0,548                        0,947
# 144                      0,216                        1,392
# 145                      1,263                        0,758
# 146                        NaN                          NaN
#
#     Explained by: Social support Explained by: Healthy life expectancy  \
# 142                        0,133                                 0,462
# 143                        0,690                                 0,270
# 144                        0,498                                 0,631
# 145                        0,000                                 0,289
# 146                          NaN                                   NaN
#
#     Explained by: Freedom to make life choices Explained by: Generosity  \
# 142                                      0,621                    0,187
# 143                                      0,329                    0,106
# 144                                      0,103                    0,082
# 145                                      0,000                    0,089
# 146                                        NaN                      NaN
#
#     Explained by: Perceptions of corruption
# 142                                   0,544
# 143                                   0,105
# 144                                   0,034
# 145                                   0,005
# 146                                     NaN

# %%
happy_df22.columns = (happy_df22.columns
                      .str.strip()
                      .str.replace('-', ' ')
                      .str.replace('*', '')
)


happy_df22.head()
# Out:
#    RANK      Country Happiness score Whisker high Whisker low  \
# 0     1      Finland           7,821        7,886       7,756
# 1     2      Denmark           7,636        7,710       7,563
# 2     3      Iceland           7,557        7,651       7,464
# 3     4  Switzerland           7,512        7,586       7,437
# 4     5  Netherlands           7,415        7,471       7,359
#
#   Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                      2,518                        1,892
# 1                      2,226                        1,953
# 2                      2,320                        1,936
# 3                      2,153                        2,026
# 4                      2,137                        1,945
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# 0                        1,258                                 0,775
# 1                        1,243                                 0,777
# 2                        1,320                                 0,803
# 3                        1,226                                 0,822
# 4                        1,206                                 0,787
#
#   Explained by: Freedom to make life choices Explained by: Generosity  \
# 0                                      0,736                    0,109
# 1                                      0,719                    0,188
# 2                                      0,718                    0,270
# 3                                      0,677                    0,147
# 4                                      0,651                    0,271
#
#   Explained by: Perceptions of corruption
# 0                                   0,534
# 1                                   0,532
# 2                                   0,191
# 3                                   0,461
# 4                                   0,419

# %%
cols_to_drop = ["Dystopia (1.83) + residual", "Whisker high", "Whisker low", "Explained by: GDP per capita", "Explained by: Generosity", "Explained by: Perceptions of corruption"]

happy_df22 = happy_df22.drop(columns = cols_to_drop)

# %%
happy_df22.head()
# Out:
#    RANK      Country Happiness score Explained by: Social support  \
# 0     1      Finland           7,821                        1,258
# 1     2      Denmark           7,636                        1,243
# 2     3      Iceland           7,557                        1,320
# 3     4  Switzerland           7,512                        1,226
# 4     5  Netherlands           7,415                        1,206
#
#   Explained by: Healthy life expectancy  \
# 0                                 0,775
# 1                                 0,777
# 2                                 0,803
# 3                                 0,822
# 4                                 0,787
#
#   Explained by: Freedom to make life choices
# 0                                      0,736
# 1                                      0,719
# 2                                      0,718
# 3                                      0,677
# 4                                      0,651

# %%
print(happy_df22.isnull().any().any())
# Out:
# True

# %%
happy_df22.isnull().sum()
# Out:
# RANK                                          0
# Country                                       0
# Happiness score                               1
# Explained by: Social support                  1
# Explained by: Healthy life expectancy         1
# Explained by: Freedom to make life choices    1
# dtype: int64

# %%
happy_df22.head()
# Out:
#    RANK      Country Happiness score Explained by: Social support  \
# 0     1      Finland           7,821                        1,258
# 1     2      Denmark           7,636                        1,243
# 2     3      Iceland           7,557                        1,320
# 3     4  Switzerland           7,512                        1,226
# 4     5  Netherlands           7,415                        1,206
#
#   Explained by: Healthy life expectancy  \
# 0                                 0,775
# 1                                 0,777
# 2                                 0,803
# 3                                 0,822
# 4                                 0,787
#
#   Explained by: Freedom to make life choices
# 0                                      0,736
# 1                                      0,719
# 2                                      0,718
# 3                                      0,677
# 4                                      0,651

# %%
happy_df22.tail(10)
# Out:
#      RANK       Country Happiness score Explained by: Social support  \
# 137   138        Malawi           3,750                        0,279
# 138   139      Tanzania           3,702                        0,597
# 139   140  Sierra Leone           3,574                        0,416
# 140   141      Lesotho*           3,512                        0,848
# 141   142     Botswana*           3,471                        0,815
# 142   143       Rwanda*           3,268                        0,133
# 143   144      Zimbabwe           2,995                        0,690
# 144   145       Lebanon           2,955                        0,498
# 145   146   Afghanistan           2,404                        0,000
# 146   147            xx             NaN                          NaN
#
#     Explained by: Healthy life expectancy  \
# 137                                 0,388
# 138                                 0,425
# 139                                 0,273
# 140                                 0,000
# 141                                 0,280
# 142                                 0,462
# 143                                 0,270
# 144                                 0,631
# 145                                 0,289
# 146                                   NaN
#
#     Explained by: Freedom to make life choices
# 137                                      0,477
# 138                                      0,578
# 139                                      0,387
# 140                                      0,419
# 141                                      0,571
# 142                                      0,621
# 143                                      0,329
# 144                                      0,103
# 145                                      0,000
# 146                                        NaN

# %%
happy_df22.drop(146, axis=0, inplace=True)

happy_df22.tail()
# Out:
#      RANK      Country Happiness score Explained by: Social support  \
# 141   142    Botswana*           3,471                        0,815
# 142   143      Rwanda*           3,268                        0,133
# 143   144     Zimbabwe           2,995                        0,690
# 144   145      Lebanon           2,955                        0,498
# 145   146  Afghanistan           2,404                        0,000
#
#     Explained by: Healthy life expectancy  \
# 141                                 0,280
# 142                                 0,462
# 143                                 0,270
# 144                                 0,631
# 145                                 0,289
#
#     Explained by: Freedom to make life choices
# 141                                      0,571
# 142                                      0,621
# 143                                      0,329
# 144                                      0,103
# 145                                      0,000

# %%
print(happy_df22.isnull().any().any())
# Out:
# False

# %%
happy_df22['Happiness score'] = happy_df22['Happiness score'].str.replace(',', '.', regex=False)

# %%
happy_df22.head()
# Out:
#    RANK      Country Happiness score Explained by: Social support  \
# 0     1      Finland           7.821                        1,258
# 1     2      Denmark           7.636                        1,243
# 2     3      Iceland           7.557                        1,320
# 3     4  Switzerland           7.512                        1,226
# 4     5  Netherlands           7.415                        1,206
#
#   Explained by: Healthy life expectancy  \
# 0                                 0,775
# 1                                 0,777
# 2                                 0,803
# 3                                 0,822
# 4                                 0,787
#
#   Explained by: Freedom to make life choices
# 0                                      0,736
# 1                                      0,719
# 2                                      0,718
# 3                                      0,677
# 4                                      0,651

# %%
happy_df22['Country'] = happy_df22['Country'].str.replace('*', '', regex=False)

# %%
happy_df22.tail(20)
# Out:
#      RANK       Country Happiness score Explained by: Social support  \
# 126   127     Sri Lanka           4.362                        0,934
# 127   128    Madagascar           4.339                        0,645
# 128   129         Egypt           4.288                        0,732
# 129   130          Chad           4.251                        0,506
# 130   131      Ethiopia           4.241                        0,809
# 131   132         Yemen           4.197                        1,043
# 132   133    Mauritania           4.153                        0,865
# 133   134        Jordan           4.152                        0,724
# 134   135          Togo           4.112                        0,322
# 135   136         India           3.777                        0,376
# 136   137        Zambia           3.760                        0,577
# 137   138        Malawi           3.750                        0,279
# 138   139      Tanzania           3.702                        0,597
# 139   140  Sierra Leone           3.574                        0,416
# 140   141       Lesotho           3.512                        0,848
# 141   142      Botswana           3.471                        0,815
# 142   143        Rwanda           3.268                        0,133
# 143   144      Zimbabwe           2.995                        0,690
# 144   145       Lebanon           2.955                        0,498
# 145   146   Afghanistan           2.404                        0,000
#
#     Explained by: Healthy life expectancy  \
# 126                                 0,660
# 127                                 0,378
# 128                                 0,548
# 129                                 0,225
# 130                                 0,457
# 131                                 0,384
# 132                                 0,450
# 133                                 0,675
# 134                                 0,360
# 135                                 0,471
# 136                                 0,306
# 137                                 0,388
# 138                                 0,425
# 139                                 0,273
# 140                                 0,000
# 141                                 0,280
# 142                                 0,462
# 143                                 0,270
# 144                                 0,631
# 145                                 0,289
#
#     Explained by: Freedom to make life choices
# 126                                      0,529
# 127                                      0,202
# 128                                      0,469
# 129                                      0,180
# 130                                      0,472
# 131                                      0,330
# 132                                      0,304
# 133                                      0,476
# 134                                      0,292
# 135                                      0,647
# 136                                      0,525
# 137                                      0,477
# 138                                      0,578
# 139                                      0,387
# 140                                      0,419
# 141                                      0,571
# 142                                      0,621
# 143                                      0,329
# 144                                      0,103
# 145                                      0,000

# %%
edit_cols = {
    'Explained by: GDP per capita': {',': '.'},
    'Explained by: Social support': {',': '.'},
    'Explained by: Healthy life expectancy': {',': '.'},
    'Explained by: Freedom to make life choices': {',':'.'},
    'Explained by: Generosity': {',':'.'},
    'Explained by: Perceptions of corruption': {',':'.'}
}

happy_df22 = happy_df22.replace(edit_cols, regex=True)

happy_df22.tail(10)
# Out:
#      RANK       Country Happiness score Explained by: Social support  \
# 136   137        Zambia           3.760                        0.577
# 137   138        Malawi           3.750                        0.279
# 138   139      Tanzania           3.702                        0.597
# 139   140  Sierra Leone           3.574                        0.416
# 140   141       Lesotho           3.512                        0.848
# 141   142      Botswana           3.471                        0.815
# 142   143        Rwanda           3.268                        0.133
# 143   144      Zimbabwe           2.995                        0.690
# 144   145       Lebanon           2.955                        0.498
# 145   146   Afghanistan           2.404                        0.000
#
#     Explained by: Healthy life expectancy  \
# 136                                 0.306
# 137                                 0.388
# 138                                 0.425
# 139                                 0.273
# 140                                 0.000
# 141                                 0.280
# 142                                 0.462
# 143                                 0.270
# 144                                 0.631
# 145                                 0.289
#
#     Explained by: Freedom to make life choices
# 136                                      0.525
# 137                                      0.477
# 138                                      0.578
# 139                                      0.387
# 140                                      0.419
# 141                                      0.571
# 142                                      0.621
# 143                                      0.329
# 144                                      0.103
# 145                                      0.000

# %%
happy_df22["Happiness score"] = happy_df22["Happiness score"].astype(float)

# %%
happy_df22.dtypes
# Out:
# RANK                                            int64
# Country                                        object
# Happiness score                               float64
# Explained by: Social support                   object
# Explained by: Healthy life expectancy          object
# Explained by: Freedom to make life choices     object
# dtype: object

# %% [markdown]
# ## Joining Happiness DF 2021 and 2022

# %%
happy_merged = pd.merge(happy21_df, happy_df22, how="outer", on=["Country"])

# %%
happy_merged.head(20)
# Out:
#                    Country                              Region  \
# 0              Afghanistan                          South Asia
# 1                  Albania          Central and Eastern Europe
# 2                  Algeria        Middle East and North Africa
# 3                Argentina         Latin America and Caribbean
# 4                  Armenia  Commonwealth of Independent States
# 5                Australia               North America and ANZ
# 6                  Austria                      Western Europe
# 7               Azerbaijan  Commonwealth of Independent States
# 8                  Bahrain        Middle East and North Africa
# 9               Bangladesh                          South Asia
# 10                 Belarus  Commonwealth of Independent States
# 11                 Belgium                      Western Europe
# 12                   Benin                  Sub-Saharan Africa
# 13                 Bolivia         Latin America and Caribbean
# 14  Bosnia and Herzegovina          Central and Eastern Europe
# 15                Botswana                  Sub-Saharan Africa
# 16                  Brazil         Latin America and Caribbean
# 17                Bulgaria          Central and Eastern Europe
# 18            Burkina Faso                  Sub-Saharan Africa
# 19                 Burundi                  Sub-Saharan Africa
#
#     Happiness Score 21  Social Support  Healthy Life Expectancy  \
# 0                2.523           0.463                   52.493
# 1                5.117           0.697                   68.999
# 2                4.887           0.802                   66.005
# 3                5.929           0.898                   69.000
# 4                5.283           0.799                   67.055
# 5                7.183           0.940                   73.900
# 6                7.268           0.934                   73.300
# 7                5.171           0.836                   65.656
# 8                6.647           0.862                   69.495
# 9                5.025           0.693                   64.800
# 10               5.534           0.910                   66.253
# 11               6.834           0.906                   72.199
# 12               5.045           0.489                   54.713
# 13               5.716           0.810                   63.901
# 14               5.813           0.870                   68.098
# 15               3.467           0.784                   59.269
# 16               6.330           0.882                   66.601
# 17               5.266           0.931                   67.000
# 18               4.834           0.672                   54.151
# 19               3.775           0.490                   53.400
#
#     Freedom To Make Life Choices   RANK  Happiness score  \
# 0                          0.382  146.0            2.404
# 1                          0.785   90.0            5.199
# 2                          0.480   96.0            5.122
# 3                          0.828   57.0            5.967
# 4                          0.825   82.0            5.399
# 5                          0.914   12.0            7.162
# 6                          0.908   11.0            7.163
# 7                          0.814   92.0            5.173
# 8                          0.925   21.0            6.647
# 9                          0.877   94.0            5.155
# 10                         0.650   65.0            5.821
# 11                         0.783   19.0            6.805
# 12                         0.757  115.0            4.623
# 13                         0.875   71.0            5.600
# 14                         0.706   67.0            5.768
# 15                         0.824  142.0            3.471
# 16                         0.804   38.0            6.293
# 17                         0.788   85.0            5.371
# 18                         0.695  113.0            4.670
# 19                         0.626    NaN              NaN
#
#    Explained by: Social support Explained by: Healthy life expectancy  \
# 0                         0.000                                 0.289
# 1                         0.646                                 0.719
# 2                         0.970                                 0.643
# 3                         1.102                                 0.662
# 4                         0.820                                 0.668
# 5                         1.203                                 0.772
# 6                         1.165                                 0.774
# 7                         1.093                                 0.560
# 8                         1.029                                 0.625
# 9                         0.614                                 0.581
# 10                        1.157                                 0.629
# 11                        1.106                                 0.764
# 12                        0.064                                 0.335
# 13                        0.880                                 0.555
# 14                        1.068                                 0.665
# 15                        0.815                                 0.280
# 16                        1.044                                 0.615
# 17                        1.163                                 0.640
# 18                        0.565                                 0.320
# 19                          NaN                                   NaN
#
#    Explained by: Freedom to make life choices
# 0                                       0.000
# 1                                       0.511
# 2                                       0.146
# 3                                       0.555
# 4                                       0.558
# 5                                       0.676
# 6                                       0.623
# 7                                       0.601
# 8                                       0.693
# 9                                       0.622
# 10                                      0.342
# 11                                      0.492
# 12                                      0.479
# 13                                      0.627
# 14                                      0.448
# 15                                      0.571
# 16                                      0.546
# 17                                      0.563
# 18                                      0.382
# 19                                        NaN

# %%
print(happy_merged.isnull().any().any())
# Out:
# True

# %%
happy_merged.isnull().sum()
# Out:
# Country                                       0
# Region                                        3
# Happiness Score 21                            3
# Social Support                                3
# Healthy Life Expectancy                       3
# Freedom To Make Life Choices                  3
# RANK                                          6
# Happiness score                               6
# Explained by: Social support                  6
# Explained by: Healthy life expectancy         6
# Explained by: Freedom to make life choices    6
# dtype: int64

# %%
happy_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 11 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country                                     152 non-null    object
#  1   Region                                      149 non-null    object
#  2   Happiness Score 21                          149 non-null    float64
#  3   Social Support                              149 non-null    float64
#  4   Healthy Life Expectancy                     149 non-null    float64
#  5   Freedom To Make Life Choices                149 non-null    float64
#  6   RANK                                        146 non-null    float64
#  7   Happiness score                             146 non-null    float64
#  8   Explained by: Social support                146 non-null    object
#  9   Explained by: Healthy life expectancy       146 non-null    object
#  10  Explained by: Freedom to make life choices  146 non-null    object
# dtypes: float64(6), object(5)
# memory usage: 13.2+ KB

# %%
happy_merged = happy_merged.drop("RANK", axis= 1)

# %%
happy_merged.columns
# Out:
# Index(['Country', 'Region', 'Happiness Score 21', 'Social Support',
#        'Healthy Life Expectancy', 'Freedom To Make Life Choices',
#        'Happiness score', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices'],
#       dtype='object')

# %%
print(happy_merged[["Happiness Score 21", "Happiness score"]].dtypes)
# Out:
# Happiness Score 21    float64
# Happiness score       float64
# dtype: object

# %%
happy_merged['Happiness Rating Avg 21-22'] = happy_merged[['Happiness Score 21', 'Happiness score']].mean(axis=1)

# %%
happy_merged.head(20)
# Out:
#                    Country                              Region  \
# 0              Afghanistan                          South Asia
# 1                  Albania          Central and Eastern Europe
# 2                  Algeria        Middle East and North Africa
# 3                Argentina         Latin America and Caribbean
# 4                  Armenia  Commonwealth of Independent States
# 5                Australia               North America and ANZ
# 6                  Austria                      Western Europe
# 7               Azerbaijan  Commonwealth of Independent States
# 8                  Bahrain        Middle East and North Africa
# 9               Bangladesh                          South Asia
# 10                 Belarus  Commonwealth of Independent States
# 11                 Belgium                      Western Europe
# 12                   Benin                  Sub-Saharan Africa
# 13                 Bolivia         Latin America and Caribbean
# 14  Bosnia and Herzegovina          Central and Eastern Europe
# 15                Botswana                  Sub-Saharan Africa
# 16                  Brazil         Latin America and Caribbean
# 17                Bulgaria          Central and Eastern Europe
# 18            Burkina Faso                  Sub-Saharan Africa
# 19                 Burundi                  Sub-Saharan Africa
#
#     Happiness Score 21  Social Support  Healthy Life Expectancy  \
# 0                2.523           0.463                   52.493
# 1                5.117           0.697                   68.999
# 2                4.887           0.802                   66.005
# 3                5.929           0.898                   69.000
# 4                5.283           0.799                   67.055
# 5                7.183           0.940                   73.900
# 6                7.268           0.934                   73.300
# 7                5.171           0.836                   65.656
# 8                6.647           0.862                   69.495
# 9                5.025           0.693                   64.800
# 10               5.534           0.910                   66.253
# 11               6.834           0.906                   72.199
# 12               5.045           0.489                   54.713
# 13               5.716           0.810                   63.901
# 14               5.813           0.870                   68.098
# 15               3.467           0.784                   59.269
# 16               6.330           0.882                   66.601
# 17               5.266           0.931                   67.000
# 18               4.834           0.672                   54.151
# 19               3.775           0.490                   53.400
#
#     Freedom To Make Life Choices  Happiness score  \
# 0                          0.382            2.404
# 1                          0.785            5.199
# 2                          0.480            5.122
# 3                          0.828            5.967
# 4                          0.825            5.399
# 5                          0.914            7.162
# 6                          0.908            7.163
# 7                          0.814            5.173
# 8                          0.925            6.647
# 9                          0.877            5.155
# 10                         0.650            5.821
# 11                         0.783            6.805
# 12                         0.757            4.623
# 13                         0.875            5.600
# 14                         0.706            5.768
# 15                         0.824            3.471
# 16                         0.804            6.293
# 17                         0.788            5.371
# 18                         0.695            4.670
# 19                         0.626              NaN
#
#    Explained by: Social support Explained by: Healthy life expectancy  \
# 0                         0.000                                 0.289
# 1                         0.646                                 0.719
# 2                         0.970                                 0.643
# 3                         1.102                                 0.662
# 4                         0.820                                 0.668
# 5                         1.203                                 0.772
# 6                         1.165                                 0.774
# 7                         1.093                                 0.560
# 8                         1.029                                 0.625
# 9                         0.614                                 0.581
# 10                        1.157                                 0.629
# 11                        1.106                                 0.764
# 12                        0.064                                 0.335
# 13                        0.880                                 0.555
# 14                        1.068                                 0.665
# 15                        0.815                                 0.280
# 16                        1.044                                 0.615
# 17                        1.163                                 0.640
# 18                        0.565                                 0.320
# 19                          NaN                                   NaN
#
#    Explained by: Freedom to make life choices  Happiness Rating Avg 21-22
# 0                                       0.000                      2.4635
# 1                                       0.511                      5.1580
# 2                                       0.146                      5.0045
# 3                                       0.555                      5.9480
# 4                                       0.558                      5.3410
# 5                                       0.676                      7.1725
# 6                                       0.623                      7.2155
# 7                                       0.601                      5.1720
# 8                                       0.693                      6.6470
# 9                                       0.622                      5.0900
# 10                                      0.342                      5.6775
# 11                                      0.492                      6.8195
# 12                                      0.479                      4.8340
# 13                                      0.627                      5.6580
# 14                                      0.448                      5.7905
# 15                                      0.571                      3.4690
# 16                                      0.546                      6.3115
# 17                                      0.563                      5.3185
# 18                                      0.382                      4.7520
# 19                                        NaN                      3.7750
