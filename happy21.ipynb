# %%
import pandas as pd
import numpy
import matplotlib as plt
from pandas import DataFrame
import random

# %%
happy21_df = pd.read_csv("C:\\Users\\pwurt\\documents\\DA_pathway\\M3\\World_Happy\\World_Happiness_Report\\.venv\\happiness_report_22\\2021.csv")

happy21_df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
happy21_df.columns = happy21_df.columns.str.title()

happy21_df.head()
# Out:
#   Country Name Regional Indicator  Ladder Score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard Error Of Ladder Score  Upperwhisker  Lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged Gdp Per Capita  Social Support  Healthy Life Expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
happy21_df.columns
# Out:
# Index(['Country Name', 'Regional Indicator', 'Ladder Score',
#        'Standard Error Of Ladder Score', 'Upperwhisker', 'Lowerwhisker',
#        'Logged Gdp Per Capita', 'Social Support', 'Healthy Life Expectancy',
#        'Freedom To Make Life Choices', 'Generosity',
#        'Perceptions Of Corruption', 'Ladder Score In Dystopia',
#        'Explained By: Log Gdp Per Capita', 'Explained By: Social Support',
#        'Explained By: Healthy Life Expectancy',
#        'Explained By: Freedom To Make Life Choices',
#        'Explained By: Generosity', 'Explained By: Perceptions Of Corruption',
#        'Dystopia + Residual'],
#       dtype='object')

# %%
print(happy21_df.isnull().any().any())
# Out:
# False

# %%
happy21_df = happy21_df.rename(columns={'Country Name': 'Country', 'Regional Indicator': 'Region', 'Ladder Score': 'Happiness Score'})

# %%
happy21_df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Score',
#        'Standard Error Of Ladder Score', 'Upperwhisker', 'Lowerwhisker',
#        'Logged Gdp Per Capita', 'Social Support', 'Healthy Life Expectancy',
#        'Freedom To Make Life Choices', 'Generosity',
#        'Perceptions Of Corruption', 'Ladder Score In Dystopia',
#        'Explained By: Log Gdp Per Capita', 'Explained By: Social Support',
#        'Explained By: Healthy Life Expectancy',
#        'Explained By: Freedom To Make Life Choices',
#        'Explained By: Generosity', 'Explained By: Perceptions Of Corruption',
#        'Dystopia + Residual'],
#       dtype='object')

# %%
cols_to_drop21 = ['Standard Error Of Ladder Score', 'Logged Gdp Per Capita', 'Healthy Life Expectancy', 'Freedom To Make Life Choices', 'Generosity', 'Perceptions Of Corruption', 'Ladder Score In Dystopia', 'Explained By: Log Gdp Per Capita', 'Dystopia + Residual']

happy21_df = happy21_df.drop(columns = cols_to_drop21)

# %%
happy21_df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Score', 'Upperwhisker', 'Lowerwhisker',
#        'Social Support', 'Explained By: Social Support',
#        'Explained By: Healthy Life Expectancy',
#        'Explained By: Freedom To Make Life Choices',
#        'Explained By: Generosity', 'Explained By: Perceptions Of Corruption'],
#       dtype='object')

# %%
happy21_df.tail()
# Out:
#          Country              Region  Happiness Score  Upperwhisker  \
# 144      Lesotho  Sub-Saharan Africa            3.512         3.748
# 145     Botswana  Sub-Saharan Africa            3.467         3.611
# 146       Rwanda  Sub-Saharan Africa            3.415         3.548
# 147     Zimbabwe  Sub-Saharan Africa            3.145         3.259
# 148  Afghanistan          South Asia            2.523         2.596
#
#      Lowerwhisker  Social Support  Explained By: Social Support  \
# 144         3.276           0.787                         0.731
# 145         3.322           0.784                         0.724
# 146         3.282           0.552                         0.202
# 147         3.030           0.750                         0.649
# 148         2.449           0.463                         0.000
#
#      Explained By: Healthy Life Expectancy  \
# 144                                  0.007
# 145                                  0.340
# ...

# %%
happy21_df.head()
# Out:
#        Country          Region  Happiness Score  Upperwhisker  Lowerwhisker  \
# 0      Finland  Western Europe            7.842         7.904         7.780
# 1      Denmark  Western Europe            7.620         7.687         7.552
# 2  Switzerland  Western Europe            7.571         7.643         7.500
# 3      Iceland  Western Europe            7.554         7.670         7.438
# 4  Netherlands  Western Europe            7.464         7.518         7.410
#
#    Social Support  Explained By: Social Support  \
# 0           0.954                         1.106
# 1           0.954                         1.108
# 2           0.942                         1.079
# 3           0.983                         1.172
# 4           0.942                         1.079
#
#    Explained By: Healthy Life Expectancy  \
# 0                                  0.741
# 1                                  0.763
# 2                                  0.816
# 3                                  0.772
# ...
